# %%
from bs4 import BeautifulSoup

# %%
with open('main.html') as f:
    soup = BeautifulSoup(f, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Moja strona
#   </title>
#  </head>
#  <body>
#   <div class="name f5">
#    Ala ma kota
#   </div>
#   <span>
#    Kot ma Ale
#   </span>
#   <ul>
#    <li>
#     Jablko
#    </li>
#    <li id="dwa">
#     Banan
#    </li>
#    <li>
#     Manadarynka
#    </li>
#   </ul>
#  </body>
# </html>

# %%
print(dir(soup))
# Out:
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'DEFAULT_INTERESTING_STRING_TYPES', 'EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'NO_PARSER_SPECIFIED_WARNING', 'ROOT_TAG_NAME', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_clone', '_decode_markup', '_event_stream', '_feed', '_find_all', '_find_one', '_format_tag', '_indent_string', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resembles_filename', '_most_recent_element', '_namespaces', '_popToTag', '_should_pretty_print', 'append', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'css', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchNextSiblings', 'fetchParents', 'fetchPrevious', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'self_and_descendants', 'setup', 'smooth', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']

# %%
res = soup.find('title')
res
# Out:
# <title>Moja strona</title>

# %%
type(res)
# Out:
# bs4.element.Tag

# %%
print(dir(res))
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES', 'EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_clone', '_event_stream', '_find_all', '_find_one', '_format_tag', '_indent_string', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_namespaces', '_should_pretty_print', 'append', 'attrs', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contents', 'css', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'encode', 'encode_contents', 'extend', 'extract', 'fetchNextSiblings', 'fetchParents', 'fetchPrevious', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'known_xml', 'name', 'namespace', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'parent', 'parentGenerator', 'parents', 'parserClass', 'parser_class', 'prefix', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'select', 'select_one', 'self_and_descendants', 'setup', 'smooth', 'sourceline', 'sourcepos', 'string', 'strings', 'stripped_strings', 'text', 'unwrap', 'wrap']

# %%
res = soup.find_all('li') 
res
# Out:
# [<li>Jablko</li>, <li id="dwa">Banan</li>, <li>Manadarynka</li>]

# %%
type(res)
# Out:
# bs4.element.ResultSet

# %%
res[0]
# Out:
# <li>Jablko</li>

# %%
soup.find_all(class_='name')
# Out:
# [<div class="name f5">Ala ma kota</div>]

# %%
soup.find(id = "dwa")
# Out:
# <li id="dwa">Banan</li>

# %%
soup.select('.name')
# Out:
# [<div class="name f5">Ala ma kota</div>]

# %%
soup.select('#dwa')
# Out:
# [<li id="dwa">Banan</li>]

# %%
soup.select('li')
# Out:
# [<li>Jablko</li>, <li id="dwa">Banan</li>, <li>Manadarynka</li>]

# %%
soup.select_one('li')
# Out:
# <li>Jablko</li>

# %%
import requests

res = requests.get('https://www.interia.pl')
print(res)
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="" lang="pl">\n<head>\n    <meta charset="UTF-8">\n    <title>Interia - Polska i świat: informacje, sport, gwiazdy.</title>\n        <meta name="Description" content="Interia - czołowy polski portal internetowy. Najlepsze serwisy informacyjne i tematyczne (Wydarzenia, Sport, Motoryzacja, Biznes, GeekWeek, Gry, Kobieta). Bezpłatna poczta e-mail." >\n            <meta name="GOOGLEBOT" content="NOODP" >\n        <meta name="referrer" content="unsafe-url" >\n        <meta name="viewport" content="width=device-width, initial-scale=1" >\n    <meta property="og:url" content="//www.interia.pl/">\n    <meta property="og:title" content="Interia - Polska i świat: informacje, sport, gwiazdy."/>\n    <meta property="og:description" content="Interia - czołowy polski portal internetowy. Najlepsze serwisy informacyjne i tematyczne (Wydarzenia, Sport, Motoryzacja, Biznes, GeekWeek, Gry, Kobieta). Bezpłatna poczta e-mail.">\n    <meta property="og:image" content="/build/images/interia-icon-fb-900x471-pattern.png">\n    <meta property="og:type" content="website" />\n    <meta property="fb:app_id" content="438577716225831">\n    <meta name="theme-color" content="#fff" >\n\n    <link rel="preconnect" href="https://ls.hit.gemius.pl">\n    <link rel="preconnect" href="https://prywatnosc.interia.pl">\n    <link rel="preconnect" href="https://iwa3.hit.interia.pl">\n    <link rel="preconnect" href="https://adc.interia.pl">\n    <link rel="preconnect" href="https://ifr-lib.interia.pl">\n    <link rel="preconnect" href="https://www.googletagmanager.com">\n    <link rel="preconnect" href="https://stats.g.doubleclick.net">\n    <link rel="preconnect" href="https://ia.hit.interia.pl">\n    <link rel="preconnect" href="https://adservice.google.com">\n    <link rel="preconnect" href="https://hub.com.pl">\n\n    <link rel="dns-prefetch" href="https://sgp2021.iplsc.com">\n    <link rel="dns-prefetch" href="https://js.iplsc.com">\n    <link rel="dns-prefetch" href="https://interia.hit.gemius.pl">\n    <link rel="dns-prefetch" href="https://iwa.iplsc.com">\n    <link rel="dns-prefetch" href="https://iwa3.hit.interia.pl">\n    <link rel="dns-prefetch" href="https://www.google-analytics.com">\n    <link rel="dns-prefetch" href="https://pogoda.interia.pl">\n    <link rel="dns-prefetch" href="https://d.iplsc.com">\n    <link rel="dns-prefetch" href="https://api.interia.nsaudience.pl">\n\n        <link rel="canonical" href="https://www.interia.pl" />\n    <link rel="manifest" href="/manifest.json" type="application/json" >\n        <link rel="icon" href="/favicon.ico" sizes="any"><!-- 48×48 -->\n    <link rel="icon" href="/favicon.svg" type="image/svg+xml">\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"/><!-- 180×180 -->\n                <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-reset.59bd09de.css" media="all" rel="stylesheet" type="text/css">\n    \n    <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-layout.d401605f.css" media="all" rel="stylesheet" type="text/css">\n    <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-news.396cbb06.css" media="all" rel="stylesheet" type="text/css">\n    <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-special.477469ef.css" media="all" rel="stylesheet" type="text/css">\n    <link rel="stylesheet" href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-app-header.7ec63e7d.css"><link rel="stylesheet" href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-app.5be1f897.css">\n        <script type="speculationrules">\n        {\n            "prefetch": [\n                {\n                    "source": "document",\n                    "where": { "and": [\n                        { "selector_matches": [".wiadspec-li .tile-a"]}\n                    ]},\n                    "eagerness": "moderate"\n                }\n            ]\ ...

# %%
content = res.text

soup = BeautifulSoup(content, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="" lang="pl">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Interia - Polska i świat: informacje, sport, gwiazdy.\n  </title>\n  <meta content="Interia - czołowy polski portal internetowy. Najlepsze serwisy informacyjne i tematyczne (Wydarzenia, Sport, Motoryzacja, Biznes, GeekWeek, Gry, Kobieta). Bezpłatna poczta e-mail." name="Description"/>\n  <meta content="NOODP" name="GOOGLEBOT"/>\n  <meta content="unsafe-url" name="referrer"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="//www.interia.pl/" property="og:url"/>\n  <meta content="Interia - Polska i świat: informacje, sport, gwiazdy." property="og:title">\n   <meta content="Interia - czołowy polski portal internetowy. Najlepsze serwisy informacyjne i tematyczne (Wydarzenia, Sport, Motoryzacja, Biznes, GeekWeek, Gry, Kobieta). Bezpłatna poczta e-mail." property="og:description"/>\n   <meta content="/build/images/interia-icon-fb-900x471-pattern.png" property="og:image"/>\n   <meta content="website" property="og:type">\n    <meta content="438577716225831" property="fb:app_id"/>\n    <meta content="#fff" name="theme-color"/>\n    <link href="https://ls.hit.gemius.pl" rel="preconnect"/>\n    <link href="https://prywatnosc.interia.pl" rel="preconnect"/>\n    <link href="https://iwa3.hit.interia.pl" rel="preconnect"/>\n    <link href="https://adc.interia.pl" rel="preconnect"/>\n    <link href="https://ifr-lib.interia.pl" rel="preconnect"/>\n    <link href="https://www.googletagmanager.com" rel="preconnect"/>\n    <link href="https://stats.g.doubleclick.net" rel="preconnect"/>\n    <link href="https://ia.hit.interia.pl" rel="preconnect"/>\n    <link href="https://adservice.google.com" rel="preconnect"/>\n    <link href="https://hub.com.pl" rel="preconnect"/>\n    <link href="https://sgp2021.iplsc.com" rel="dns-prefetch"/>\n    <link href="https://js.iplsc.com" rel="dns-prefetch"/>\n    <link href="https://interia.hit.gemius.pl" rel="dns-prefetch"/>\n    <link href="https://iwa.iplsc.com" rel="dns-prefetch"/>\n    <link href="https://iwa3.hit.interia.pl" rel="dns-prefetch"/>\n    <link href="https://www.google-analytics.com" rel="dns-prefetch"/>\n    <link href="https://pogoda.interia.pl" rel="dns-prefetch"/>\n    <link href="https://d.iplsc.com" rel="dns-prefetch"/>\n    <link href="https://api.interia.nsaudience.pl" rel="dns-prefetch"/>\n    <link href="https://www.interia.pl" rel="canonical">\n     <link href="/manifest.json" rel="manifest" type="application/json"/>\n     <link href="/favicon.ico" rel="icon" sizes="any"/>\n     <!-- 48×48 -->\n     <link href="/favicon.svg" rel="icon" type="image/svg+xml"/>\n     <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180">\n      <!-- 180×180 -->\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-reset.59bd09de.css" media="all" rel="stylesheet" type="text/css"/>\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-layout.d401605f.css" media="all" rel="stylesheet" type="text/css"/>\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-news.396cbb06.css" media="all" rel="stylesheet" type="text/css"/>\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-special.477469ef.css" media="all" rel="stylesheet" type="text/css"/>\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-app-header.7ec63e7d.css" rel="stylesheet"/>\n      <link href="https://sgp2021.iplsc.com/build/7b7747ec045ae606eb720a1222f56098-app.5be1f897.css" rel="stylesheet"/>\n      <script type="speculationrules">\n       {\n            "prefetch": [\n                {\n                    "source": "document",\n                    "where": { "and": [\n                        { "selector_matches": [".wiadspec-li .tile-a"]}\n                    ]},\n                    "eagerness": "moderate"\n                }\n            ]\n ...

# %%
soup.select('.title-text')
# Out:
# [<span class="title-text">Razem podjęło decyzję. "Rząd Donalda Tuska zawiódł ludzi"</span>,
#  <span class="title-text">Rosjanie chwalą się postępami. Kolejne tereny Ukrainy w rękach okupanta</span>,
#  <span class="title-text">Mistrzowie Polski zaczęli doskonale. Rywale walczą o wyrównanie</span>,
#  <span class="title-text">Zagraniczne media o Andrzeju Dudzie: Atut obronny</span>,
#  <span class="title-text">Pięciu złapali, jeden wciąż ucieka. "Chcieli dostać się do Moskwy"</span>,
#  <span class="title-text">Tragiczne odkrycie w Odrze. "Skrępowane ręce i nogi"</span>,
#  <span class="title-text">Zapytali Polaków o związki partnerskie. Ponad połowa odpowiedziała zgodnie</span>,
#  <span class="title-text">Wigilia dniem wolnym od pracy? Jest głos z Episkopatu</span>,
#  <span class="title-text">Pena przerwał milczenie ws. Szczęsnego. W Hiszpanii aż huczy</span>,
#  <span class="title-text">Gwiazdy Hollywood nie miały odwagi. Jeden po drugim odmawiali roli</span>,
#  <span class="title-text">Nowy trend w odchudzaniu. "Coraz więcej Polaków"</span>,
#  <span class="title-text">Przez budowę tunelu stracili dorobek życia. Mieszkają w hotelu</span>,
#  <span class="title-text">Widzowie tęsknią za legendarnym serialem. Powstaje jego następca</span>,
#  <span class="title-text">Katarzyna Bonda o najnowszej książce "W głąb" i psychiatrii dziecięcej </span>,
#  <span class="title-text">Ruszyli przed zakład, chcą wolności dla "Buddy". Banery i okrzyki</span>,
#  <span class="title-text">Nietypowa prośba zoo w Polsce. Ludzie na nią zareagowali i wiele zyskali</span>,
#  <span class="title-text">"Najgorszy silnik świata" ma konkurencję. Problem dotyczy 760 tys. aut </span>,
#  <span class="title-text">Śmiertelnie jadowity wąż zastawia podstępną pułapkę. Łatwo w nią wpaść</span>,
#  <span class="title-text">Skandal w El Clasico wstrząsnął kibicami. Gwiazda Barcelony ofiarą ataku</span>,
#  <span class="title-text">Jego wyścigi ogląda nawet Kubica. Dramat polskiego talentu. Traci szanse na F1 </span>,
#  <span class="title-text">Słupki rtęci ostro w górę. Na drogach jednak zagrożenie</span>,
#  <span class="title-text">L4 po nowemu. Od listopada zmiany w wystawianiu zwolnień</span>,
#  <span class="title-text">Kosmos niszczy wzrok? Problemy uczestników misji Polaris Dawn</span>,
#  <span class="title-text">Jedz suszony i świeży. Chroni przed starzeniem, infekcjami i cukrzycą</span>,
#  <span class="title-text">Celebrytka odrzuca spadek i planuje zmianę nazwiska. Wszystko dla córki</span>,
#  <span class="title-text">Na wzmocnienie, zbicie cholesterolu i lepsze trawienie. Pij właśnie teraz</span>,
#  <span class="title-text">Ida Nowakowska ma imponujące wykształcenie. Szkół tyle, że głowa mała</span>,
#  <span class="title-text">Jak wyglądały jej ostatnie dni? "Cierpienia Jadzi były niebotyczne"</span>,
#  <span class="title-text">Jego znają w Polsce wszyscy, ale kim jest jego piękna żona?</span>,
#  <span class="title-text">Rządziły w PRL-u, niedługo o nich zapomnimy. Tych imion już nie nadajemy</span>,
#  <span class="title-text">15 lat temu zwyciężył w "Mam talent". "Ćwiczyłem do 7 rano w garażu".</span>,
#  <span class="title-text">Historyczny tytuł Polki, 5 godzin i 1 minuta gry. Niebywały powrót w finale</span>,
#  <span class="title-text">Potrzeba było dopiero Lewandowskiego. Wielki wyczyn Polaka w El Clasico</span>,
#  <span class="title-text">Hiszpanie bez litości dla gwiazdy Realu. "Zrobił z siebie historycznego głupca"</span>,
#  <span class="title-text">Kłopoty Świątek, przykra wiadomość przed WTA Finals. Sabalenka może świętować</span>,
#  <span class="title-text">Hajto nie wytrzymał po El Clasico. Wziął na celownik Flicka. "Niemiecki rygor"</span>,
#  <span class="title-text">Show Roberta Lewandowskiego po El Clasico. Wszystko zostało nagrane</span>,
#  <span class="title-text">Kosmiczny bieg po rekord świata. Niezwykły sprint, padł na kolana za metą</span>,
#  <span class="title-text">Real Madryt CF - FC Barcelona. Skrót meczu. WIDEO (Eleven Sports)</span>,
#  <span class="title-text">Ancelotti ruszył do Flicka, hamulce puściły. Tego nie pokazały kamery</span>,
#  <span class="title-text">"Lewy" nie był najlepszy w Madrycie. Wyczyn innego Polaka nie do powtórzenia</span>,
#  <span class="title-text">Dwa sety w meczu mistrzyni olimpijskiej i koniec. Kluczowe wieści dla Świątek </span>,
#  <span class="title-text">Wielki mistrz powrócił na trasy i już punktuje. Niesamowity awans Brazylijczyka</span>,
#  <span class="title-text">Bała się ich cała sportowa Polska. Ruszył z pięściami w obronie brata</span>,
#  <span class="title-text">Nowy zakaz w UE. Od 1 stycznia tego już nie kupisz</span>,
#  <span class="title-text">Nowy obowiązek dla właścicieli psów i kotów. Koszty poniosą sami</span>,
#  <span class="title-text">W tym sezonie nie tylko złoto się świeci. "Księżycowy metal" bije rekordy</span>,
#  <span class="title-text">Kiedy można jeździć komunikacją miejską bez biletu?</span>,
#  <span class="title-text">Wigilia w tym roku wolna od pracy? To możliwe</span>,
#  <span class="title-text">Pożyczasz pieniądze od rodziny? Tłumaczymy, co z podatkiem</span>,
#  <span class="title-text">Budowa pomnika utknęła w martwym punkcie. Wciąż nie wiadomo czy powstanie</span>,
#  <span class="title-text">Politycy chcą walczyć z luką płacową. "Jest opór przedsiębiorców"</span>,
#  <span class="title-text">Zwolnienie lekarskie i wypłata. Kiedy dostaniesz 100 proc.?</span>,
#  <span class="title-text">Renta rodzinna. Te dokumenty dostarcz do ZUS, 31 października mija termin</span>,
#  <span class="title-text">Czy fotoradary mają tolerancję? O ile można przekroczyć prędkość?</span>,
#  <span class="title-text">Pędziła pod prąd prosto na inne pojazdy. Nawet nie dotknęła hamulca</span>,
#  <span class="title-text">Samemu wymieniasz opony? Lekarze na SOR tylko na to czekają</span>,
#  <span class="title-text">Nowy odcinek zakopianki spowodował nowe korki. Miastu grozi paraliż</span>,
#  <span class="title-text">52-latkę czeka więzienie. Wszystko przez nagranie z internetu</span>,
#  <span class="title-text">Rewolucja na MOP-ach w Polsce. Pojawi się na nich kluczowe rozwiązanie</span>,
#  <span class="title-text">Coraz więcej wypadków z udziałem pieszych. Czy to efekt zmian w przepisach?</span>,
#  <span class="title-text">Czy pieszy ma pierwszeństwo, jeśli nie przechodzi po przejściu?</span>,
#  <span class="title-text">Polacy rzucili się po rozbite auta z USA. Gigantyczny wzrost </span>,
#  <span class="title-text">Kierowcy widzą znak B-32c i nie wiedzą - można jechać czy trzeba zawrócić</span>,
#  <span class="title-text">Kluczowa obwodnica na Śląsku wreszcie będzie dokończona. Padły terminy</span>,
#  <span class="title-text">Pani Elżbieta ma 70 lat i żałuje jednego. Dziś przestrzega młode pokolenie</span>,
#  <span class="title-text">Ile dać na wypominki? Podajemy konkretne kwoty </span>,
#  <span class="title-text">Aromat rozchodzi sie po całym domu. Tradycyjny staropolski przepis!</span>,
#  <span class="title-text">Co zrobić, by znicz palił się dłużej? Bardzo prosty trik</span>,
#  <span class="title-text">Jesienny kociołek nie tylko na chłodne dni</span>,
#  <span class="title-text">Ma więcej polifenoli niż jabłka. W proszku zastąpi ci cukier i słodziki</span>,
#  <span class="title-text">To klucz do zdrowego śniadania. Zajadaj ze smakiem każdego ranka</span>,
#  <span class="title-text">Jak pielęgnować siwe włosy? Kluczowy jeden zabieg </span>,
#  <span class="title-text">Do starszych mówią jak do dzieci. Tę szkodliwą formę uznano za przemoc</span>,
#  <span class="title-text">"Ewa gotuje": Zupa pomidorowa z pstrągiem</span>,
#  <span class="title-text">Przelewanie i bulgotanie w jelitach to zły znak. Odwiedź gastroenterologa</span>,
#  <span class="title-text">Domowa herbata na odporność i stany zapalne. Trzy zdrowe składniki</span>,
#  <span class="title-text">Jest przyjemniejsza w smaku i ma mnóstwo witamin. Zastąpi zwykłą rzodkiewkę</span>,
#  <span class="title-text">"Rajski ptak" w doniczce. Zapamiętaj zasady, oczaruje cię trwałymi kwiatami</span>,
#  <span class="title-text">Łatwe ćwiczenie całego ciała. Spalisz dużo kalorii, wzmocnisz brzuch</span>,
#  <span class="title-text">Babcia gotowała ją co drugi dzień. Bomba witamin, do tego pyszna!</span>,
#  <span class="title-text">Prosty i aromatyczny sos sałatkowy. Do zrobienia w mniej niż minutę</span>,
#  <span class="title-text">Zresetowali rzekę i zmienili jej nurt. Efekt zaskoczył nawet niedowiarków</span>,
#  <span class="title-text">Dobre wieści dla posiadaczy kilkuletnich sprzętów do TV</span>,
#  <span class="title-text">20 niezwykle dochodowych marek w rękach jednej firmy z USA. Jakiej?</span>,
#  <span class="title-text">Fani popularnej marki samochodów nie mogą przejść obojętnie obok tej informacji</span>,
#  <span class="title-text">Ile godzin ma doba? Czas na quiz o... czasie. 8/10 to już sukces</span>,
#  <span class="title-text">Wirtualny przedmiot w grze za 339 zł - to dużo czy mało?</span>,
#  <span class="title-text">Skąd węgiel wziął się w Układzie Słonecznym? Nowe odkrycie może to wyjaśnić</span>,
#  <span class="title-text">"Niebieski jeż" powrócił! Hit końcówki 2024 roku?</span>,
#  <span class="title-text">Wskrzeszą mitycznego ptaka. Powoduje obsesję u ludzi</span>,
#  <span class="title-text">Praca na stojąco? Stanie nie jest wcale zdrowsze od siedzenia</span>,
#  <span class="title-text">Czym jest czas? Rozmawiamy z fizykiem i geografem o naturze czasu</span>,
#  <span class="title-text">Sztuczna inteligencja pilnuje lekarzy. Sprawdza, jakie leki podają</span>,
#  <span class="title-text">Mars ma lód, który może sprzyjać życiu. Potwierdzają to badania</span>,
#  <span class="title-text">Halloweenowy zestaw horrorów na Netflix. Filmy, które przerażają </span>,
#  <span class="title-text">Karkówka po cygańsku. Zrób, a nie pożałujesz</span>,
#  <span class="title-text">Rosół, jakiego jeszcze nie jadłeś. Ewa Wachowicz dodaje sekretny składnik </span>,
#  <span class="title-text">Szybka sałatka dla gości</span>,
#  <span class="title-text">Zniknie ze stołu, zanim zdąży dobrze ostygnąć</span>,
#  <span class="title-text">Idealnie miękkie ciasto na pierogi</span>,
#  <span class="title-text">Biją na głowę zwykłe śledzie. Delikatniejsze, tańsze, uchodzą za przysmak</span>,
#  <span class="title-text">Tradycyjne danie peerelowskich jadłodajni. Podbija serca smakoszy</span>,
#  <span class="title-text">Roladki studenckie - przepis, do którego warto wracać</span>,
#  <span class="title-text">Skrop mięso. Kotlety zachwycą chrupiącą skórką i delikatnym środkiem</span>,
#  <span class="title-text">Obiad dla gości na Wszystkich Świętych</span>,
#  <span class="title-text">Puszysty jak chmurka omlet. Smakowite śniadanie z prostych składników </span>,
#  <span class="title-text">Tańsza alternatywa dla AC. Nie każdy kierowca zna tę opcję</span>,
#  <span class="title-text">Najmodniejszy płaszcz sezonu. Pasuje do wszystkiego, a przy tym wyszczupla</span>,
#  <span class="title-text">Mieszkanie jak z katalogu bez wydawania fortuny. Nowa usługa robi furorę</span>,
#  <span class="title-text">Już nie tylko starsze osoby. Choroba może dotknąć każdego</span>,
#  <span class="title-text"><span class="span-nocolor">To koniec. </span><span class="span-colored" style="--marker-color: #E70E8E">Gwiazdy potwierdziły rozstanie na antenie</span><span class="span-nocolor">. I to w 6. rocznicę</span></span>,
#  <span class="title-text"><span class="span-nocolor">Zwrot akcji ws. Badacha i Szpaka. </span><span class="span-colored" style="--marker-color: #E70E8E">Zaskakujące sceny na antenie</span></span>,
#  <span class="title-text"><span class="span-nocolor">Drzyzga nie chciała mieszkać w centrum miasta. </span><span class="span-colored" style="--marker-color: #E70E8E">Dojeżdża do pracy 300 km</span></span>,
#  <span class="title-text"><span class="span-colored" style="--marker-color: #E70E8E">Sikora odpowiada na pytania o drugą połówkę.</span><span class="span-nocolor"> Teraz wszystko jasne</span></span>,
#  <span class="title-text"><span class="span-nocolor">Prawda ws. przeszłości Dębskiej wyszła na jaw. </span><span class="span-colored" style="--marker-color: #E70E8E">Nagle ogłosiła</span></span>,
#  <span class="title-text">Przepowiedziała, co czeka nas od 28 października. Nie będzie za różowo</span>,
#  <span class="title-text">W listopadzie otworzy się "numerologiczna brama". Oto co nas czeka </span>,
#  <span class="title-text"><span class="span-colored" style="--marker-color: #E70E8E">Doda już tego nie ukrywa.</span><span class="span-nocolor"> Tak wygląda stan zdrowia jej ukochanego pupila</span></span>,
#  <span class="title-text"><span class="span-nocolor">Rosati lansuje się w halloweenowej kreacji. </span><span class="span-colored" style="--marker-color: #E70E8E">Niebywałe, za kogo się przebrała</span></span>,
#  <span class="title-text"><span class="span-nocolor">Wojciechowska skończyła 50 lat i zalała się łzami. </span><span class="span-colored" style="--marker-color: #E70E8E">Wyszło, dlaczego...</span></span>,
#  <span class="title-text"><span class="span-nocolor">Marta Żmuda Trzebiatowska ujawnia zmagania z chorobą. </span><span class="span-colored" style="--marker-color: #E70E8E">"Wracam do siebie"</span></span>,
#  <span class="title-text"><span class="span-nocolor">Do Justyny Gradek los znów się uśmiechnął. </span><span class="span-colored" style="--marker-color: #E70E8E">Znalazła kolejnego bogacza</span></span>,
#  <span class="title-text"><span class="span-colored" style="--marker-color: #E70E8E">Fani nie mają już wątpliwości ws. Grzeszczak i Buzały.</span><span class="span-nocolor"> Chodzi o zdjęcia</span></span>,
#  <span class="title-text"><span class="span-nocolor">Gwiazdy na koncercie "Nadzieja-Razem dla Was!". </span><span class="span-colored" style="--marker-color: #E70E8E">Wiadomo, co z gażami</span></span>,
#  <span class="title-text"><span class="span-colored" style="--marker-color: #E70E8E">Ewa Mrozowska unika pracy z celebrytami.</span><span class="span-nocolor"> Ma ku temu ważny powód</span></span>,
#  <span class="title-text"><span class="span-colored" style="--marker-color: #E70E8E">Sandra Kubicka padła ofiarą nękania w klubie.</span><span class="span-nocolor"> "Uciekałam przed creepem"</span></span>,
#  <span class="title-text">"M jak miłość": Wszystkie kłamstwa Martyny ujrzą światło dzienne</span>,
#  <span class="title-text">Przejmujący komunikat żony Borysa Szyca. "Jestem wrakiem" </span>,
#  <span class="title-text">Skompromitowany aktor wraca na ekrany. Skandal odbił się szerokim echem</span>,
#  <span class="title-text">Dopiero co kręcił w Polsce film. Otrzymał wyjątkowe wyróżnienie</span>,
#  <span class="title-text">Koniec zdjęć do 4. sezonu Wiedźmina. Kiedy premiera?</span>,
#  <span class="title-text">Wypełnij krótką ankietę i oceń nasze serwisy!</span>,
#  <span class="title-text">Widzowie grzmią po koncercie w TVP. "Gwiazdy zrzekną się honorarium?"</span>,
#  <span class="title-text">Modelki błyskawicznie podbiły Polskę. "Nie obyło się bez błędów"</span>,
#  <span class="title-text">Hollywoodzka gwiazda rozkwita na salonach! To jej druga ciąża </span>,
#  <span class="title-text">Netflix wyłożył miliony. Film zbiera mieszane opinie</span>,
#  <span class="title-text">Przez 20 lat walczyły o niezależność. Co słychać u znanych bliźniaczek?</span>,
#  <span class="title-text">Zagrał epizod w "Titanicu". Wciąż zgarnia tantiemy </span>,
#  <span class="title-text">TVP ujawniło, czy artyści zarobią na charytatywnym koncercie. Jest jasny...</span>,
#  <span class="title-text">Jako młoda artystka szokowała wizerunkiem. Co robi dzisiaj?</span>,
#  <span class="title-text">"Gwiazdowski mówi Interii"</span>,
#  <span class="title-text">"Zbliżenia" Alicji Resich </span>,
#  <span class="title-text">Białkowski Zielona Interia</span>,
#  <span class="title-text">"Zdanowicz pomiędzy wersami"</span>,
#  <span class="title-text">Kot dostał głupawki. Ale wybryki!</span>,
#  <span class="title-text">Lepiej nie zadzierać z głodnymi kozami</span>,
#  <span class="title-text">Pies prowadzi... konia na smyczy. Zabawne wideo</span>,
#  <span class="title-text">Piękna sceneria. Niestety ucierpiał dron</span>,
#  <span class="title-text">Duża ryba nie dała za wygraną. Skończył w wodzie</span>,
#  <span class="title-text">Mrożące krew w żyłach nagranie. Co za prędkość!</span>,
#  <span class="title-text">Głodny wielbłąd nie oszczędził turystki</span>,
#  <span class="title-text">Ukłon i smakołyk. Niezwykłe podziękowanie</span>,
#  <span class="title-text">Kup w aptece i dodaj do pralki. Ręczniki będą mięciutkie i puszyste</span>,
#  <span class="title-text">Obniża cholesterol, wymiata złogi, wspomaga jelita. Jedz zamiast mięsa</span>,
#  <span class="title-text">Jak zrobić domowy proszek do zmywarki?</span>,
#  <span class="title-text">Wybierz jedno pióro z pięciu. Dowiesz się ważnej rzeczy o sobie</span>,
#  <span class="title-text">Połącz z ciepłym mlekiem i wypij na noc. Zyskasz lepszy sen i płaski brzuch</span>,
#  <span class="title-text">Wyrośnięte ciasto z owocami. Prosty trik, który uchroni przed zakalcem</span>,
#  <span class="title-text">Choroba, która powoli odbiera sprawność. Coraz więcej przypadków sarkopenii</span>,
#  <span class="title-text">Błędy w wapnowaniu gleby jesienią. Wyrządzisz więcej szkód niż pożytku</span>,
#  <span class="title-text">Ma niewielkie wymagania, za to wygląda zjawiskowo</span>,
#  <span class="title-text">Te warzywa zbierz dopiero po solidnym przechłodzeniu</span>,
#  <span class="title-text">Najgroźniejsze szkodniki tui - niektóre potrafią zniszczyć cały krzew</span>,
#  <span class="title-text">Co zrobić, żeby nie śmierdziało z kompostownika? Wystarczy jedna rzecz</span>,
#  <span class="title-text">Co zrobić ze spadami owoców. Gdzie wyrzucać, czy można je kompostować?</span>,
#  <span class="title-text">Byliny wieloletnie, które długo kwitną. Zioła, kwiaty i solitery</span>,
#  <span class="title-text">Podczas sadzenia wymieszaj z podłożem. To pomoc dla roślin cebulowych</span>,
#  <span class="title-text">Zapomniane warzywo wraca do ogrodów. Wężymord – uprawa i zastosowanie</span>,
#  <span class="title-text">Podkreśla kobiece piękno</span>,
#  <span class="title-text">Portfolio, które cię zainteresuje</span>,
#  <span class="title-text">Prostota i elegancja we wnętrzu </span>,
#  <span class="title-text">Mistrzowski specjał z przepisu Marioli</span>,
#  <span class="title-text">Galeria fantastycznych ujęć</span>,
#  <span class="title-text">Unikatowa energia</span>,
#  <span class="title-text">Zmysłowość w portretach</span>,
#  <span class="title-text">Świetny pomysł na rodzinny obiad</span>,
#  <span class="title-text">Zielony wir w jeziorze. Jak wytłumaczyć to zjawisko?</span>,
#  <span class="title-text">Weekendowy rarytas</span>,
#  <span class="title-text">Rewelacyjny smalec bez grama mięsa</span>,
#  <span class="title-text">Ponadczasowy salon w bieli i beżu</span>,
#  <span class="title-text">Tajemnica masywu Tamu. Największy wulkan świata ukryty pod falami Pacyfiku?</span>,
#  <span class="title-text">Pyszna sałatka na każdą okazję</span>,
#  <span class="title-text">Pomysł na jesienny ogród </span>,
#  <span class="title-text">Aranżacja ogrodu z pomysłem </span>,
#  <span class="title-text">Wejdź do krainy słodkości i zagraj w Candy Rain 6!</span>,
#  <span class="title-text">Zagraj w Butterfly Kyodai - kultową grę mahjong!</span>,
#  <span class="title-text">Lubisz łamigłówki? Zagraj w Wood Block Journey!</span>,
#  <span class="title-text">Zagraj w Kulki - tylko 10% graczy zdobyło 20 000 punktów. </span>,
#  <span class="title-text">Autorski videocast Roberta Gwiazdowskiego, w którym komentuje bieżącą sytuację gospodarczą w Polsce.</span>,
#  <span class="title-text">Cykl videocastów ekologicznych "Przemysław Białkowski podcast" w serwisie Zielona Interia.</span>,
#  <span class="title-text">Zdanowicz pomiędzy wersami to podcast video, którego nowe odcinki co tydzień można oglądać na łamach Interii.</span>,
#  <span class="title-text">Nieoczywiste tematy, odważne pytania i różnorodne perspektywy prezentowane przez gości.</span>,
#  <span class="title-text">"Zbliżenia" Alicji Resich </span>]

# %%
titles = soup.select('.title-text')
for title in titles:
    print(title.get_text())
# Out:
# Razem podjęło decyzję. "Rząd Donalda Tuska zawiódł ludzi"
# Rosjanie chwalą się postępami. Kolejne tereny Ukrainy w rękach okupanta
# Mistrzowie Polski zaczęli doskonale. Rywale walczą o wyrównanie
# Zagraniczne media o Andrzeju Dudzie: Atut obronny
# Pięciu złapali, jeden wciąż ucieka. "Chcieli dostać się do Moskwy"
# Tragiczne odkrycie w Odrze. "Skrępowane ręce i nogi"
# Zapytali Polaków o związki partnerskie. Ponad połowa odpowiedziała zgodnie
# Wigilia dniem wolnym od pracy? Jest głos z Episkopatu
# Pena przerwał milczenie ws. Szczęsnego. W Hiszpanii aż huczy
# Gwiazdy Hollywood nie miały odwagi. Jeden po drugim odmawiali roli
# Nowy trend w odchudzaniu. "Coraz więcej Polaków"
# Przez budowę tunelu stracili dorobek życia. Mieszkają w hotelu
# Widzowie tęsknią za legendarnym serialem. Powstaje jego następca
# Katarzyna Bonda o najnowszej książce "W głąb" i psychiatrii dziecięcej
# Ruszyli przed zakład, chcą wolności dla "Buddy". Banery i okrzyki
# Nietypowa prośba zoo w Polsce. Ludzie na nią zareagowali i wiele zyskali
# "Najgorszy silnik świata" ma konkurencję. Problem dotyczy 760 tys. aut
# Śmiertelnie jadowity wąż zastawia podstępną pułapkę. Łatwo w nią wpaść
# Skandal w El Clasico wstrząsnął kibicami. Gwiazda Barcelony ofiarą ataku
# Jego wyścigi ogląda nawet Kubica. Dramat polskiego talentu. Traci szanse na F1
# Słupki rtęci ostro w górę. Na drogach jednak zagrożenie
# L4 po nowemu. Od listopada zmiany w wystawianiu zwolnień
# Kosmos niszczy wzrok? Problemy uczestników misji Polaris Dawn
# Jedz suszony i świeży. Chroni przed starzeniem, infekcjami i cukrzycą
# Celebrytka odrzuca spadek i planuje zmianę nazwiska. Wszystko dla córki
# Na wzmocnienie, zbicie cholesterolu i lepsze trawienie. Pij właśnie teraz
# Ida Nowakowska ma imponujące wykształcenie. Szkół tyle, że głowa mała
# Jak wyglądały jej ostatnie dni? "Cierpienia Jadzi były niebotyczne"
# Jego znają w Polsce wszyscy, ale kim jest jego piękna żona?
# Rządziły w PRL-u, niedługo o nich zapomnimy. Tych imion już nie nadajemy
# 15 lat temu zwyciężył w "Mam talent". "Ćwiczyłem do 7 rano w garażu".
# Historyczny tytuł Polki, 5 godzin i 1 minuta gry. Niebywały powrót w finale
# Potrzeba było dopiero Lewandowskiego. Wielki wyczyn Polaka w El Clasico
# Hiszpanie bez litości dla gwiazdy Realu. "Zrobił z siebie historycznego głupca"
# Kłopoty Świątek, przykra wiadomość przed WTA Finals. Sabalenka może świętować
# Hajto nie wytrzymał po El Clasico. Wziął na celownik Flicka. "Niemiecki rygor"
# Show Roberta Lewandowskiego po El Clasico. Wszystko zostało nagrane
# Kosmiczny bieg po rekord świata. Niezwykły sprint, padł na kolana za metą
# Real Madryt CF - FC Barcelona. Skrót meczu. WIDEO (Eleven Sports)
# Ancelotti ruszył do Flicka, hamulce puściły. Tego nie pokazały kamery
# "Lewy" nie był najlepszy w Madrycie. Wyczyn innego Polaka nie do powtórzenia
# Dwa sety w meczu mistrzyni olimpijskiej i koniec. Kluczowe wieści dla Świątek
# Wielki mistrz powrócił na trasy i już punktuje. Niesamowity awans Brazylijczyka
# Bała się ich cała sportowa Polska. Ruszył z pięściami w obronie brata
# Nowy zakaz w UE. Od 1 stycznia tego już nie kupisz
# Nowy obowiązek dla właścicieli psów i kotów. Koszty poniosą sami
# W tym sezonie nie tylko złoto się świeci. "Księżycowy metal" bije rekordy
# Kiedy można jeździć komunikacją miejską bez biletu?
# Wigilia w tym roku wolna od pracy? To możliwe
# Pożyczasz pieniądze od rodziny? Tłumaczymy, co z podatkiem
# Budowa pomnika utknęła w martwym punkcie. Wciąż nie wiadomo czy powstanie
# Politycy chcą walczyć z luką płacową. "Jest opór przedsiębiorców"
# Zwolnienie lekarskie i wypłata. Kiedy dostaniesz 100 proc.?
# Renta rodzinna. Te dokumenty dostarcz do ZUS, 31 października mija termin
# Czy fotoradary mają tolerancję? O ile można przekroczyć prędkość?
# Pędziła pod prąd prosto na inne pojazdy. Nawet nie dotknęła hamulca
# Samemu wymieniasz opony? Lekarze na SOR tylko na to czekają
# Nowy odcinek zakopianki spowodował nowe korki. Miastu grozi paraliż
# 52-latkę czeka więzienie. Wszystko przez nagranie z internetu
# Rewolucja na MOP-ach w Polsce. Pojawi się na nich kluczowe rozwiązanie
# Coraz więcej wypadków z udziałem pieszych. Czy to efekt zmian w przepisach?
# Czy pieszy ma pierwszeństwo, jeśli nie przechodzi po przejściu?
# Polacy rzucili się po rozbite auta z USA. Gigantyczny wzrost
# Kierowcy widzą znak B-32c i nie wiedzą - można jechać czy trzeba zawrócić
# Kluczowa obwodnica na Śląsku wreszcie będzie dokończona. Padły terminy
# Pani Elżbieta ma 70 lat i żałuje jednego. Dziś przestrzega młode pokolenie
# Ile dać na wypominki? Podajemy konkretne kwoty
# Aromat rozchodzi sie po całym domu. Tradycyjny staropolski przepis!
# Co zrobić, by znicz palił się dłużej? Bardzo prosty trik
# Jesienny kociołek nie tylko na chłodne dni
# Ma więcej polifenoli niż jabłka. W proszku zastąpi ci cukier i słodziki
# To klucz do zdrowego śniadania. Zajadaj ze smakiem każdego ranka
# Jak pielęgnować siwe włosy? Kluczowy jeden zabieg
# Do starszych mówią jak do dzieci. Tę szkodliwą formę uznano za przemoc
# "Ewa gotuje": Zupa pomidorowa z pstrągiem
# Przelewanie i bulgotanie w jelitach to zły znak. Odwiedź gastroenterologa
# Domowa herbata na odporność i stany zapalne. Trzy zdrowe składniki
# Jest przyjemniejsza w smaku i ma mnóstwo witamin. Zastąpi zwykłą rzodkiewkę
# "Rajski ptak" w doniczce. Zapamiętaj zasady, oczaruje cię trwałymi kwiatami
# Łatwe ćwiczenie całego ciała. Spalisz dużo kalorii, wzmocnisz brzuch
# Babcia gotowała ją co drugi dzień. Bomba witamin, do tego pyszna!
# Prosty i aromatyczny sos sałatkowy. Do zrobienia w mniej niż minutę
# Zresetowali rzekę i zmienili jej nurt. Efekt zaskoczył nawet niedowiarków
# Dobre wieści dla posiadaczy kilkuletnich sprzętów do TV
# 20 niezwykle dochodowych marek w rękach jednej firmy z USA. Jakiej?
# Fani popularnej marki samochodów nie mogą przejść obojętnie obok tej informacji
# Ile godzin ma doba? Czas na quiz o... czasie. 8/10 to już sukces
# Wirtualny przedmiot w grze za 339 zł - to dużo czy mało?
# Skąd węgiel wziął się w Układzie Słonecznym? Nowe odkrycie może to wyjaśnić
# "Niebieski jeż" powrócił! Hit końcówki 2024 roku?
# Wskrzeszą mitycznego ptaka. Powoduje obsesję u ludzi
# Praca na stojąco? Stanie nie jest wcale zdrowsze od siedzenia
# Czym jest czas? Rozmawiamy z fizykiem i geografem o naturze czasu
# Sztuczna inteligencja pilnuje lekarzy. Sprawdza, jakie leki podają
# Mars ma lód, który może sprzyjać życiu. Potwierdzają to badania
# Halloweenowy zestaw horrorów na Netflix. Filmy, które przerażają
# Karkówka po cygańsku. Zrób, a nie pożałujesz
# Rosół, jakiego jeszcze nie jadłeś. Ewa Wachowicz dodaje sekretny składnik
# Szybka sałatka dla gości
# Zniknie ze stołu, zanim zdąży dobrze ostygnąć
# Idealnie miękkie ciasto na pierogi
# Biją na głowę zwykłe śledzie. Delikatniejsze, tańsze, uchodzą za przysmak
# Tradycyjne danie peerelowskich jadłodajni. Podbija serca smakoszy
# Roladki studenckie - przepis, do którego warto wracać
# Skrop mięso. Kotlety zachwycą chrupiącą skórką i delikatnym środkiem
# Obiad dla gości na Wszystkich Świętych
# Puszysty jak chmurka omlet. Smakowite śniadanie z prostych składników
# Tańsza alternatywa dla AC. Nie każdy kierowca zna tę opcję
# Najmodniejszy płaszcz sezonu. Pasuje do wszystkiego, a przy tym wyszczupla
# Mieszkanie jak z katalogu bez wydawania fortuny. Nowa usługa robi furorę
# Już nie tylko starsze osoby. Choroba może dotknąć każdego
# To koniec. Gwiazdy potwierdziły rozstanie na antenie. I to w 6. rocznicę
# Zwrot akcji ws. Badacha i Szpaka. Zaskakujące sceny na antenie
# Drzyzga nie chciała mieszkać w centrum miasta. Dojeżdża do pracy 300 km
# Sikora odpowiada na pytania o drugą połówkę. Teraz wszystko jasne
# Prawda ws. przeszłości Dębskiej wyszła na jaw. Nagle ogłosiła
# Przepowiedziała, co czeka nas od 28 października. Nie będzie za różowo
# W listopadzie otworzy się "numerologiczna brama". Oto co nas czeka
# Doda już tego nie ukrywa. Tak wygląda stan zdrowia jej ukochanego pupila
# Rosati lansuje się w halloweenowej kreacji. Niebywałe, za kogo się przebrała
# Wojciechowska skończyła 50 lat i zalała się łzami. Wyszło, dlaczego...
# Marta Żmuda Trzebiatowska ujawnia zmagania z chorobą. "Wracam do siebie"
# Do Justyny Gradek los znów się uśmiechnął. Znalazła kolejnego bogacza
# Fani nie mają już wątpliwości ws. Grzeszczak i Buzały. Chodzi o zdjęcia
# Gwiazdy na koncercie "Nadzieja-Razem dla Was!". Wiadomo, co z gażami
# Ewa Mrozowska unika pracy z celebrytami. Ma ku temu ważny powód
# Sandra Kubicka padła ofiarą nękania w klubie. "Uciekałam przed creepem"
# "M jak miłość": Wszystkie kłamstwa Martyny ujrzą światło dzienne
# Przejmujący komunikat żony Borysa Szyca. "Jestem wrakiem"
# Skompromitowany aktor wraca na ekrany. Skandal odbił się szerokim echem
# Dopiero co kręcił w Polsce film. Otrzymał wyjątkowe wyróżnienie
# Koniec zdjęć do 4. sezonu Wiedźmina. Kiedy premiera?
# Wypełnij krótką ankietę i oceń nasze serwisy!
# Widzowie grzmią po koncercie w TVP. "Gwiazdy zrzekną się honorarium?"
# Modelki błyskawicznie podbiły Polskę. "Nie obyło się bez błędów"
# Hollywoodzka gwiazda rozkwita na salonach! To jej druga ciąża
# Netflix wyłożył miliony. Film zbiera mieszane opinie
# Przez 20 lat walczyły o niezależność. Co słychać u znanych bliźniaczek?
# Zagrał epizod w "Titanicu". Wciąż zgarnia tantiemy
# TVP ujawniło, czy artyści zarobią na charytatywnym koncercie. Jest jasny...
# Jako młoda artystka szokowała wizerunkiem. Co robi dzisiaj?
# "Gwiazdowski mówi Interii"
# "Zbliżenia" Alicji Resich
# Białkowski Zielona Interia
# "Zdanowicz pomiędzy wersami"
# Kot dostał głupawki. Ale wybryki!
# Lepiej nie zadzierać z głodnymi kozami
# Pies prowadzi... konia na smyczy. Zabawne wideo
# Piękna sceneria. Niestety ucierpiał dron
# Duża ryba nie dała za wygraną. Skończył w wodzie
# Mrożące krew w żyłach nagranie. Co za prędkość!
# Głodny wielbłąd nie oszczędził turystki
# Ukłon i smakołyk. Niezwykłe podziękowanie
# Kup w aptece i dodaj do pralki. Ręczniki będą mięciutkie i puszyste
# Obniża cholesterol, wymiata złogi, wspomaga jelita. Jedz zamiast mięsa
# Jak zrobić domowy proszek do zmywarki?
# Wybierz jedno pióro z pięciu. Dowiesz się ważnej rzeczy o sobie
# Połącz z ciepłym mlekiem i wypij na noc. Zyskasz lepszy sen i płaski brzuch
# Wyrośnięte ciasto z owocami. Prosty trik, który uchroni przed zakalcem
# Choroba, która powoli odbiera sprawność. Coraz więcej przypadków sarkopenii
# Błędy w wapnowaniu gleby jesienią. Wyrządzisz więcej szkód niż pożytku
# Ma niewielkie wymagania, za to wygląda zjawiskowo
# Te warzywa zbierz dopiero po solidnym przechłodzeniu
# Najgroźniejsze szkodniki tui - niektóre potrafią zniszczyć cały krzew
# Co zrobić, żeby nie śmierdziało z kompostownika? Wystarczy jedna rzecz
# Co zrobić ze spadami owoców. Gdzie wyrzucać, czy można je kompostować?
# Byliny wieloletnie, które długo kwitną. Zioła, kwiaty i solitery
# Podczas sadzenia wymieszaj z podłożem. To pomoc dla roślin cebulowych
# Zapomniane warzywo wraca do ogrodów. Wężymord – uprawa i zastosowanie
# Podkreśla kobiece piękno
# Portfolio, które cię zainteresuje
# Prostota i elegancja we wnętrzu
# Mistrzowski specjał z przepisu Marioli
# Galeria fantastycznych ujęć
# Unikatowa energia
# Zmysłowość w portretach
# Świetny pomysł na rodzinny obiad
# Zielony wir w jeziorze. Jak wytłumaczyć to zjawisko?
# Weekendowy rarytas
# Rewelacyjny smalec bez grama mięsa
# Ponadczasowy salon w bieli i beżu
# Tajemnica masywu Tamu. Największy wulkan świata ukryty pod falami Pacyfiku?
# Pyszna sałatka na każdą okazję
# Pomysł na jesienny ogród
# Aranżacja ogrodu z pomysłem
# Wejdź do krainy słodkości i zagraj w Candy Rain 6!
# Zagraj w Butterfly Kyodai - kultową grę mahjong!
# Lubisz łamigłówki? Zagraj w Wood Block Journey!
# Zagraj w Kulki - tylko 10% graczy zdobyło 20 000 punktów.
# Autorski videocast Roberta Gwiazdowskiego, w którym komentuje bieżącą sytuację gospodarczą w Polsce.
# Cykl videocastów ekologicznych "Przemysław Białkowski podcast" w serwisie Zielona Interia.
# Zdanowicz pomiędzy wersami to podcast video, którego nowe odcinki co tydzień można oglądać na łamach Interii.
# Nieoczywiste tematy, odważne pytania i różnorodne perspektywy prezentowane przez gości.
# "Zbliżenia" Alicji Resich
