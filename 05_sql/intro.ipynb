# %% [markdown]
# #### chinook.db

# %% [markdown]
# ![image.png](attachment:74e57483-ec82-4ca5-aee4-beeda6a43cd9.png)

# %% [markdown]
# ##### 1. Wyświetlenie wszystkich artystów:
#
#
#
# Opis: Zwraca wszystkie rekordy z tabeli artists z informacjami o artystach.

# %% [markdown]
# ##### 2. Wyświetlenie wszystkich klientów:
#
#
#
# Opis: Zwraca wszystkie dane klientów z tabeli customers.

# %% [markdown]
# ##### 3. Wyświetlenie imion wszystkich klientów:
#
#
#
# Opis: Zwraca tylko imiona wszystkich klientów.

# %% [markdown]
# ##### 4. Wyświetlenie imion wszystkich klientów nadając kolumnie wynikowej alias 'name':
#
#
#
# Opis: Zwraca tylko imiona wszystkich klientów.

# %% [markdown]
# ##### 5. Wyświetlenie imion, nazwisk i krajów klientów:
#
#
#
# Opis: Zwraca imiona, nazwiska i kraje wszystkich klientów.

# %% [markdown]
# ##### 6. Klienci z Brazylii:
#
#
#
# Opis: Zwraca imiona i nazwiska klientów z Brazylii.

# %% [markdown]
# ##### 7. Klienci spoza Brazylii:
#
#
#
# Opis: Zwraca klientów, którzy nie są z Brazylii.

# %% [markdown]
# ##### 8. Klienci z krajami których nazwa jest większa (w porządku alfabetycznym) niż 'Brazil':
#
#
#
# Opis: Zwraca klientów z krajami alfabetycznie większymi niż 'Brazil'.

# %% [markdown]
# ##### 9. Klienci z krajami pasującymi do wzorca:
#
#
#
# Opis: Zwraca klientów, których kraje pasują do wzorca.

# %% [markdown]
# ##### 10. Klienci z Brazylii lub imionami zaczynającymi się na 'D':
#
#
#
# Opis: Zwraca klientów z Brazylii lub o imionach zaczynających się na 'D'.

# %% [markdown]
# ##### 11. Klienci z USA i imionami zaczynającymi się na 'D':
#
#
#
# Opis: Zwraca klientów z USA o imionach zaczynających się na 'D'.

# %% [markdown]
# ##### 12. Klienci spoza USA:
#
#
#
# Opis: Zwraca klientów, którzy nie są z USA.

# %% [markdown]
# ##### 13. Klienci spoza USA z aliasami:
#
#
#
# Opis: Zwraca klientów spoza USA z użyciem aliasów dla kolumn.

# %% [markdown]
# ##### 14. Średni identyfikator przedstawiciela wsparcia dla klientów w różnych krajach:
#
#
#
# Opis: Zwraca średni identyfikator przedstawiciela wsparcia dla klientów, grupując według kraju, ale tylko dla tych krajów.

# %% [markdown]
# ##### 15. Zliczanie liczby klientów w każdym kraju:
#
#
#
# Opis: Zwraca liczbę klientów w każdym kraju, grupując dane według kraju.

# %% [markdown]
# ##### 16. Średni identyfikator przedstawiciela wsparcia dla klientów w różnych krajach, gdzie średni SupportRepId jest większy niż 1:
#
#
#
# Opis: Zwraca średni identyfikator przedstawiciela wsparcia dla klientów, grupując według kraju, ale tylko dla tych krajów, gdzie średni SupportRepId jest większy niż 1.

# %% [markdown]
# ##### 17. Wyświetlenie 5 pierwszych klientów:
#
#
#
# Opis: Zwraca pierwszych 5 klientów z tabeli customers.

# %% [markdown]
# ##### 18. Wyświetlenie 10 klientów z pominięciem pierwszych 5:
#
#
#
# Opis: Zwraca 10 klientów, pomijając pierwsze 5 rekordów.

# %% [markdown]
# ##### 19. Klienci posortowani według imienia w porządku rosnącym:
#
#
#
# Opis: Zwraca wszystkich klientów posortowanych według imienia w porządku rosnącym.

# %% [markdown]
# ##### 20. Klienci posortowani według imienia w porządku malejącym:
#
#
#
# Opis: Zwraca wszystkich klientów posortowanych według imienia w porządku malejącym.

# %% [markdown]
# A teraz to samo w Pythonie.

# %%
# import biblioteki

# %%
# fetchall

# %%
# fetchone

# %%
# fetchmany
